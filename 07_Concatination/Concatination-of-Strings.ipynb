# %%
a='Data'
b=' Analyst'  #give space after quotes if you want space in words
a+b
# Out:
# 'Data Analyst'

# %%
'Data' + 'Analyst'
# Out:
# 'DataAnalyst'

# %%
# boolean values

bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(100)
# Out:
# True

# %%
bool(-5)
# Out:
# True

# %%
# boolean of string
bool('Data_Analyst')
# Out:
# True

# %%
bool('') #empty string
# Out:
# False
