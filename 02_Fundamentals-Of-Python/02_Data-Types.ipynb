# %% [markdown]
# ## Data type is a classification that tells the computer what kind of data a variable can store and what operations can be performed on it.
#
# ## Following are Data Types use in python:
#  🍁 number         - int (integer)/ float (fraction)
#  🍁 Character      - str
#  🍁 Boolean        - True/ false
#  🍁 Nothing        - None
#  🍁 complex number - ex- x+iy
#
# ex-

# %% [markdown]
# ## string

# %%
c="Data"
type(c)
# Out:
# str

# %% [markdown]
# ## Boolean
# ## In python True has 1 value and false has 0

# %%
True - False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Nothing

# %%
f= None
f

# %%
type(f)
# Out:
# NoneType

# %% [markdown]
# ## Complex number

# %%
com = 5+6j
type(com)
# Out:
# complex

# %%
com.real
# Out:
# 5.0

# %%
com.imag
# Out:
# 6.0

# %% [markdown]
# ## Rules of defining a variable:
# It can start with alphabet or underscore character and join two words with underscore only
# ex-

# %%
5=a
# Out:
#   Cell In[10], line 1
#     5=a
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
_name= "Data_Analyst"
_name
# Out:
# 'Data_Analyst'

# %%
Data_Analytics = "Data"
Data_Analytics
# Out:
# 'Data'

# %% [markdown]
# ## We can change the data type by using Type casting

# %%
name ="2"
name = int(name)
type(name)
# Out:
# int

# %%
s=4.5
type(int(s))
# Out:
# int

# %%
bool(0)
# Out:
# False

# %%
a = "DataAnalyst"   ##### we can not covert alphabets values to other data type only if str value is numeric then we can conert it to int or float data type
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 a = "DataAnalyst"   ##### we can not covert alphabets values to other data type only if str value is numeric then we can conert it to int or flost data type
# ----> 2 int(a)
#
# ValueError: invalid literal for int() with base 10: 'DataAnalyst'
