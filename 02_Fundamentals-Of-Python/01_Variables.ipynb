# %% [markdown]
# ## Variables are the placeholder to store various data which we can use in wriiting a code (It is a reserverd memory space to store VALUE)
# ex-

# %%
a=3
a
# Out:
# 3

# %% [markdown]
# # If we redifined value of a i.e. gave new value it will take new value only
# ex-

# %%
a=4.5
a
# Out:
# 4.5
