# %% [markdown]
# ## Keywords-
# ## Predifine words that holds special meaning and have specific purpose
# ex- print, type

# %%
print("Hello World")
# Out:
# Hello World

# %%
a= 5
type(a)
# Out:
# int

# %% [markdown]
# ## Following are some keywords which are widely use:
#
# False  ;   None   ;     True  ;   as   ;    and  ;   assert ;    async  ;    await   ;   break  ;
# calss  ;    continue ;  del   ;   def  ;    elif ;   else   ;    except ;    finally  ;  for  ;
# from   ;   Global   ;   if    ;  import ;    in   ;   is     ;   lambda  ;   nonlocal ;  not  ;
# or     ;   pass     ;   raise ;   return ;    try ;   while  ;    with   ;    yield

# %% [markdown]
# ## ✨ Plus Point
# # What is indentation? - leave spaces to write code with specific aligment

# %%
if 3>2:
   print("greater")  # indentation - Here leave spaces to write code with specific aligment
# Out:
# greater

# %% [markdown]
# ## Note- variables should not be keywords to ovide overriding them
