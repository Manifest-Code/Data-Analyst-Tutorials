# %% [markdown]
# ## Real World Examples of APIs
#
# - API-Based Communication Between Frontend, Backend, and Database in Social Media Apps
# - API-Driven Architecture of Mobile Payment Platforms like Gpay
# - Understanding Google Search: Backend APIs and Result Delivery

# %% [markdown]
# ## API's
#
# - API stand for application programming interface.
# - API is a set of rules and protocols that allows software to interact with each other.

# %% [markdown]
# ## How it works
#
# - When you add your login details it goes to backend code and then goes to database to check if user details are already exist or not.
# - If details matched it will logg in to portal otherwise it will ask to sign in
#
# ![image.png](API's.png)
