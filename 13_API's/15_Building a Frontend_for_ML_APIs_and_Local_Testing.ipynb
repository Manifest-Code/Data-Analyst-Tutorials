# %% [markdown]
# ## Building a Frontend for ML APIs and Local Testing
#
# Topics:
#
# 1) Creating a Simple HTML/CSS Frontend
#    - Input form for user data
#    - Submit button to trigger API call
#    - Displaying prediction result on the page
#
# 2) Testing ML API Locally
#    - Start Flask server
#    - Run HTML file and interact with the backend
#
# Creating frontend
#
# ![image.png](Frontend.png)

# %% [markdown]
# ## Create index1.html file in tempplates folder
# - use app2.py fiile for previous code

# %% [markdown]
# - wrote index1.html file and def home() in app2.py file

# %% [markdown]
# - After writting index1.html file run app2.py file

# %% [markdown]
# - to make form more attractive use this prmopt in chatgpt
#
# ```
# Following is my html form, your task is:
# 1) add CSS code for it to make it more attractive and beautiful.
# 2) the form should be in center of the dispaly, there should be some margin from the top
# 3) choose the color theme of your choice
#
# HTML Code:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Birth Weight Form</title>
# </head>
# <body>
#     <h1> Predict Birth Weight of your child:</h1>
#     <form action = '/predict' methods = 'POST'>
#         <label>Gestation</label><br>
#         <input name="gestation" type="number"><br>
#
#         <label>Parity</label><br>
#         <input name="parity" type="number"><br>
#
#         <label>Age</label><br>
#         <input name="age" type="number"><br>
#
#         <label>Height</label><br>
#         <input name="height" type="number"><br>
#
#         <label>Weight</label><br>
#         <input name="weight" type="number"><br>
#
#         <label>Smoke</label><br>
#         <input name="smoke" type="number"><br>
#
#     </form>
# </body>
# </html>

# %% [markdown]
# copy and paste the code given by chatgpt in html file

# %% [markdown]
# - created app3.py for cleaned data

# %% [markdown]
# - add predict birth weight as header in html file and and return the rediction

# %% [markdown]
# - run app3.py file
