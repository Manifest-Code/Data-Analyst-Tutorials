# %% [markdown]
# ## create a flask application for privious trained model

# %% [markdown]
# - ## create a app2.ipynb file

# %% [markdown]
# - open postman app
# - type the url http://127.0.0.1:5000/predict
# - select body
# - in that select raw
# -  provide the user data which is in 12_Model_Development_and_Serialization.ipynb file:
#   ```
#     {
#     "gestation":[302.0],
#     "parity" : [1]	,
#     "age":[22.0],
#     "height":[70.0],
#     "weight":[170.0],
#     "smoke":[1.0]
#     }
#
# - click on send
