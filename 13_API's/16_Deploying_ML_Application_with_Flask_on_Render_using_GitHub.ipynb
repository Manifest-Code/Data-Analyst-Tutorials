# %% [markdown]
# ## Deploying ML Application with Flask on Render using GitHub
#
# Topics:
# 1) Introduction to Cloud Deployment Platforms
#    - Why use Render?
#    - Free vs Paid services
#
# 2) Preparing Project for Deployment
#    - Organizing code structure
#    - Creating requirements.txt
#
# 3) GitHub Setup
#    - Creating a GitHub repository
#    - Committing & pushing the code
#
# 4) Deployment on Render
#    - Creating a Render web service
#    - Connecting GitHub repo
#    - Setting build and start commands
#    - Setting environment variables
#
# 5) Post Deployment Testing
#    - Accessing the deployed URL
#    - Testing API with frontend
#    - Debugging common errors

# %% [markdown]
# - ## create .gitignore file and added files which doesn't want to deploy to github.
# - ## also extract model.pkl file from model folder and deleted model folder

# %% [markdown]
# - Pushed code to git hub
# - after that create account on render (https://dashboard.render.com/) with your github acct
# - click on the new button in that dropdown select web services
# - select the git hub repo where your code is written and add **gunicorn app3:app** at start command
# - scroll down and select free version
# - ##add a repo birth_weight_predictor.
#
# - It will show building
# - status will change to "inprogress" To -> "Live"
# - then it had provided the link under your and now if you open it you can see your aaplication (https://birth-weight-predictor-3-5z88.onrender.com/)
