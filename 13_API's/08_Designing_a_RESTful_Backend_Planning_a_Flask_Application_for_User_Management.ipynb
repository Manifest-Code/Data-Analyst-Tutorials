# %% [markdown]
# - Understanding GET, POST, PUT and DELETE Methods in Flask
#
# - Downloading the POSTMAN tool for API testing

# %% [markdown]
# ## users application: { Get, Post, Put, Delete }
#
# ```
# Instagram / Snapchat (new user):
# 1. Register ->  create an account       ## post method will be used as its secure to create data
#     - username -> John
#     - password ->
# 2. Login -> get/retrieve account       ## get method
#     - John Wick (Update example)
# 3. Update -> update account           ## Put method
# 4. Delete -> delete account           ## deletet method

# %% [markdown]
# Diagram: CRUD (4 operations)
#
# ```
# Letter    Operation                 URL
# C          Create      -> "http://127.0.0.1:5000/create_user"
# R          Retrieve    ->  "http://127.0.0.1:5000/get_user/<int:id>"
# U          Update      -> "http://127.0.0.1:5000/update_user/<int:id>"
# D          Delete      -> "http://127.0.0.1:5000/delete_user/<int:id>"
