# %% [markdown]
# ## 🍁☃️ see the app_1.py file for this.

# %% [markdown]
# in form_1.html - enctype="multipart/form-data" is use cause if we don't write this theres a posibility that it form will not show in backend

# %% [markdown]
# ## in postman type your endpoint url to create a userfile in your system after user submit there file. -> http://127.0.0.1:5000/upload
#
# ## choose the method as post and
# - go to body
#   - form-Data
#      - choose file from text/file option which is infont of key section
#      - key - add the variable name you have given in your code for user file
#              here i have given file as a variable name in form_1.html
#      - value - upload a csv file # as in code we have given condition to uplad only csv file
#
# - then 'send'
