# %% [markdown]
# ## Wrote code in auth.py file
#
# after that open a postman
#
# - Get - add your http link
# - click send
# - will get Login here as output
#
# - then edit http link and add extension /profile
# - send
# - it will return else statement error
#
# - go to headers
# - add key = x-api-key  and value = myapikey
# send
# - it will show profile page
