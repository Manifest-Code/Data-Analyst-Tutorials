# %% [markdown]
# ## 📕 Files Handling basic 🌼

# %%
open("file.txt", 'r' ) #if there is no any file, and you open it in read mode it will throw an error
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 open("file.txt", 'r' ) #if there is no any file, and you open it in read mode it will throw an error
#
# File d:\IMP Documents\Coding Practice\Data Analyst -PW class\Data Analyst - PW Class - Vs code\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'

# %% [markdown]
# #mode
# #r >> read mode
# #w>> write mode
# #a >> append mode
# #r+>> both reading and writing

# %%
file = open("file.txt", "w") #w>>write mode, if a file is not there it will create the file.txt and then read it

# %%
file.write("Hello, This is my first line in the text file")  #number below is no of bytes you have written
# Out:
# 45

# %% [markdown]
# - ✨ as of now if you open the written file you will not be able to see any text in file
# - ✨ to see you have to close the file

# %%
file.close()

# %%
file #file attributes
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='utf-8'>

# %%
file.closed  #if file is closed it will return true else false
# Out:
# True

# %%
file = open("file.txt", "r")

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
file.name
# Out:
# 'file.txt'

# %%
file.mode
# Out:
# 'r'

# %%
file.closed
# Out:
# True

# %%
file.write("This is my second line") #this will not be executed, throw an error>> file is closed>>you can not write anything in closed file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 file.write("This is my second line") #this will not be executed, throw an error>> file is closed>>you can not write anything in closed file
#
# ValueError: I/O operation on closed file.

# %%
file = open("file.txt", "w") #it will truncate(delete) all earlier contetnt and make a fresh file.txt

# %%
file.close()

# %%
file = open("file.txt", 'w')
file.write("This is my first line \n")
file.write("This is my second line \n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %%
file = open("file.txt", "w")
file.write("This is fifth line") #all earlier content will deleted
file.close()

# %%
file = open("file.txt", "w")
file.write("This is my first line\n")
file.write("This is my second line\n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %% [markdown]
# ## you can append the file

# %%
file = open("file.txt", 'a')
file.write("This is fifth line")
file.close()

# %% [markdown]
# - you can't write in a file if you open it with read mode

# %%
file = open("file.txt", 'r')

# %%
file.write("this is a another line")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 file.write("this is a another line")
#
# UnsupportedOperation: not writable

# %%
file
# Out:
# <_io.TextIOWrapper name='file.txt' mode='r' encoding='utf-8'>

# %%
#various way of printing lines
for i in file:
    print(i)
# Out:
# This is my first line
#
# This is my second line
#
# This is my third line
#
# This is my fourth line
#
# This is fifth line

# %%
file.read() #here the cursor/pointer is at last position thats why it gives 2 quotes
# Out:
# ''

# %%
print(file.read()) # same the cursor/pointer is at last position

# %%
file.tell() #it tells the current position of the cursor
# Out:
# 112

# %%
file.seek(0)  #it will bring cursor to start of the the file
# Out:
# 0

# %%
file = open("file.txt", 'r')
file.seek(0) 
print(file.read())     #it will read everything from starting
file.close()
# Out:
# This is my first line
# This is my second line
# This is my third line
# This is my fourth line
# This is fifth line

# %%
file = open("file.txt", 'r')
file.seek(0) 
print(file.readline())     #it will only read the first line
file.close()
# Out:
# This is my first line

# %%
file = open("file.txt", 'r')
print(file.readlines())  #all the lines will be the element of a list
file.close()
# Out:
# ['This is my first line\n', 'This is my second line\n', 'This is my third line\n', 'This is my fourth line\n', 'This is fifth line']

# %%
#present working directory
# !pwd
# Out:
# /d/IMP Documents/Coding Practice/Data Analyst -PW class/Data Analyst - PW Class - Vs code/Data-Analyst-Tutorials/11_Files_Handling

# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling'

# %%
ls  # list of files present in cwd
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is C2EE-95F9
#
#  Directory of d:\IMP Documents\Coding Practice\Data Analyst -PW class\Data Analyst - PW Class - Vs code\Data-Analyst-Tutorials\11_Files_Handling
#
# 27/01/2026  04:42 pm    <DIR>          .
# 27/01/2026  04:14 pm    <DIR>          ..
# 27/01/2026  05:07 pm            15,912 01_Files_Handling_basic.ipynb
# 27/01/2026  04:48 pm               112 file.txt
#                2 File(s)         16,024 bytes
#                2 Dir(s)  249,410,289,664 bytes free

# %%
os.path.getsize("file.txt") # get size of file
# Out:
# 0

# %%
os.mkdir("test")  # create a file

# %%
os.mkdir("test/test1")  # create file test1 inside test

# %%
os.mkdir("1/2") # got error cause 1 is not made first. for system its like file name 1 is not present
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 os.mkdir("1/2")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '1/2'

# %%
# you can make multiple directries using below function
os.makedirs("1/2/3/4")

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is C2EE-95F9
#
#  Directory of d:\IMP Documents\Coding Practice\Data Analyst -PW class\Data Analyst - PW Class - Vs code\Data-Analyst-Tutorials\11_Files_Handling
#
# 27/01/2026  05:41 pm    <DIR>          .
# 27/01/2026  04:14 pm    <DIR>          ..
# 27/01/2026  05:37 pm            18,608 01_Files_Handling_basic.ipynb
# 27/01/2026  05:41 pm    <DIR>          1
# 27/01/2026  04:48 pm               112 file.txt
# 27/01/2026  05:35 pm    <DIR>          test
#                2 File(s)         18,720 bytes
#                4 Dir(s)  249,410,285,568 bytes free

# %%
os.listdir()
# Out:
# ['01_Files_Handling_basic.ipynb', '1', 'file.txt', 'test']

# %%
os.mkdir("seaborn")

# %%
os.rmdir("seaborn")  #to delete one directory without any content inside the directory

# %%
os.rmdir("test") #throw an error as test is not empty
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 os.rmdir("test") #throw an error as test is not empty
#
# OSError: [WinError 145] The directory is not empty: 'test'

# %%
import shutil
shutil.rmtree("test")

# %%
os.getcwd()
# Out:
# 'd:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling'

# %%
os.makedirs("test/test1")  # create test1 folder inside test folder

# %%
f = open("d:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling\\test\\test1\\file.txt", 'w') # create file.txt file inside test1 folder which is inside test folder

# %%
#copying the above file in the current location >> /home/jovyan/work
#shutil.copy(src, dest)

# %%
shutil.copy("d:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling\\test\\test1\\file.txt", "d:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling\\file_test")  #keep a copy at original source as well
# Out:
# 'd:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling\\file_test\\file.txt'

# %% [markdown]
# ## move a file

# %%
os.mkdir("file_test")

# %%
shutil.move("d:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling\\test\\test1\\file.txt", "d:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling\\file_test")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\AppData\Roaming\uv\python\cpython-3.15.0a2-windows-x86_64-none\Lib\shutil.py:918, in move(src, dst, copy_function)
#     917 try:
# --> 918     os.rename(src, real_dst)
#     919 except OSError:
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling\\test\\test1\\file.txt' -> 'd:\\IMP Documents\\Coding Practice\\Data Analyst -PW class\\Data Analyst - PW Class - Vs code\\Data-Analyst-Tutorials\\11_Files_Handling\\file_test\\file.txt'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[6], line 1
# ...

# %% [markdown]
# - move will remove the file from original source to destination source

# %% [markdown]
# ## To read/write a file without everythime closing a file beforehand.

# %%
with open("file.txt", 'w') as f:
    f.write("This is my first line")

# %%
with open("file.txt", 'r') as f:
    line = f.readline()
    print(line)
# Out:
# This is my first line
