# %% [markdown]
# ## Type casting/ Type convrtion -- chnage the data type

# %%
'2' + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 '2' + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
a='2'
b= 3
int(a)+b
# Out:
# 5

# %%
a='2'
print(type(a))
print(type(int(a)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# float to int	 
a=3.4
int(a)
# Out:
# 3

# %%
# Integer to float
a=3
b= float(a)
b
# Out:
# 3.0

# %%
# sting to float

a= '2'
b= float(a)
b
# Out:
# 2.0

# %%
a='Data'  # charachter can not be converted into number so if string value is alphabet characters then it won't convert in other data type

# integer to string
a= int(a)
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 a='Data'  # charachter can not be converted into number so if string value is alphabet characters then it won't convert in other data type
#       3 # integer to string
# ----> 4 a= int(a)
#       5 a
#
# ValueError: invalid literal for int() with base 10: 'Data'

# %%
a=5
b= str(a)
b
# Out:
# '5'

# %% [markdown]
# ## ✅ There are two types of Type Casting -
#    Implicite and Explicite
#
# ## 📕 Implicite Type Casting- Python understands the standerd data types itself
#       Python automatically converts smaller / lower data types into larger / compatible data types to avoid data loss.
#
# ## Key Characteristics
#   💎 Done by Python
#   💎 No data loss
#   💎 Happens during operations
#
#   ex-

# %%
a= 5
type(a)
# Out:
# int

# %% [markdown]
# ## Explicit Type Casting
#   The programmer converts one data type into another using built-in functions.
#
# ## Common Functions
#   int(), float(), str(), bool(), list(), tuple(), set()

# %%
x = "10"
y = int(x)

y
# Out:
# 10

# %%
type(y)
# Out:
# int
