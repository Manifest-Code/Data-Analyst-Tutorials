# %% [markdown]
# <h3 align = "Center"><b>Data Toolkit</b></h3>

# %% [markdown]
# ## Q1 What is NumPy, and why is it widely used in Python?
#
# - What is NumPy?
#   - NumPy (Numerical Python) is a powerful Python library used for working with arrays and mathematical operations.
#   - It provides a special data structure called the ndarray (N-dimensional array), which is faster and more efficient than Python
#     lists   for numerical calculations.
#
# - Why is NumPy widely used in Python?
#   1. Fast Performance: NumPy is written in C, so calculations are much faster than normal Python loops.
#   2. Efficient Array Operations: You can perform operations on entire arrays at once.
#       ```
#          import numpy as np
#          arr = np.array([1, 2, 3])
#          print(arr * 2)   # output - [2 4 6]
#   3. Memory Efficient: NumPy arrays use less memory compared to Python lists.
#   4. Mathematical & Statistical Functions:
#      - It provides built-in functions like:
#        - mean()
#        - median()
#        - sum()
#        - standard deviation
#        - linear algebra operations
#   5. Foundation for Data Science Libraries: Libraries like: Pandas, Matplotlib, Scikit-learn are built on top of NumPy.
#   6. Multi-dimensional Arrays: Supports 1D, 2D, and higher-dimensional arrays easily.

# %% [markdown]
# ## Q2 How does broadcasting work in NumPy?
#
# - Broadcasting in NumPy allows you to perform arithmetic operations on arrays of different shapes without manually reshaping them.
# - It automatically expands the smaller array to match the shape of the larger array.
# - NumPy compares their shapes from right to left.
# - Two dimensions are compatible if: They are equal, or One of them is 1
# - If compatible, NumPy stretches (broadcasts) the smaller array.
#   Example:
#   ```
#      import numpy as np
#      A = np.array([[1, 2, 3],[4, 5, 6]])
#      B = np.array([10, 20, 30])
#      print(A + B)
#      # output - [[11 22 33][14 25 36]]

# %% [markdown]
# ## Q3 What is a Pandas DataFrame?
#
# - A Pandas DataFrame is a 2-dimensional labeled data structure in Python that looks like a table (like an Excel sheet).
# - It has: Rows and Columns
# - Each column can have different data types (numbers, text, dates, etc.)
# - Pandas DataFrame comes from the library pandas.
#   Example:
#   ```
#      import pandas as pd
#      data = {"Name": ["Amit", "Sneha", "Rahul"],
#              "Age": [20, 21, 19],
#              "Marks": [85, 90, 88]
#              }
#      df = pd.DataFrame(data)
#      print(df)
#
#       # output-
#            Name   Age  Marks
#      0     Amit   20    85
#      1     Sneha  21    90
#      2     Rahul  19    88

# %% [markdown]
# ## Q4 Explain the use of the groupby() method in Pandas.
#
# - The groupby() method in pandas is used to split data into groups based on one or more columns.
# - perform calculations on each group, and then combine the results.
# - We use it to: Calculate sum, Find mean, Count values, Get maximum / minimum, Perform other aggregate operations for each category.
#   Example:
#   ```
#      import pandas as pd
#      data = {"Department": ["IT", "HR", "IT", "HR", "Sales"],
#               "Salary": [50000, 40000, 60000, 45000, 55000]
#               }
#      df = pd.DataFrame(data)
#      result = df.groupby("Department")["Salary"].mean()
#      print(result)
#
#      # output-
#            Department
#     HR       42500
#     IT       55000
#     Sales    55000

# %% [markdown]
# ## Q5 Why is Seaborn preferred for statistical visualizations?
#
# - Seaborn is preferred for statistical visualizations because it is built specifically for creating attractive and informative statistical graphs in Python.
# - It is built on top of Matplotlib, but makes visualization much easier and more beautiful.
# - Built-in Statistical Plots
# - It provides special statistical plots like: Histogram, Boxplot, Violin plot, Bar plot, Heatmap, Pair plot, Regression plot.
# - These are designed specifically for data analysis.
# - Seaborn works very well with pandas DataFrames, making it easy to visualize structured data.
# - Automatic Statistical Calculations: It automatically: Calculates averages, Adds confidence intervals, Shows distributions, Fits regression lines, So you don’t need to compute everything manually.

# %% [markdown]
# ## Q6 What are the differences between NumPy arrays and Python lists?
#
# - NumPy Arrays:
#   - Data Type: Stores only one data type (all elements must be same type).
#   - Performance: NumPy Array is Much faster because it is implemented in C and optimized for numerical operations.
#   - Memory Usage: NumPy Array → More memory efficient.
#   - NumPy Array → Easily supports 1D, 2D, and multi-dimensional arrays.
#   - NumPy Array → Provides many built-in functions like: mean(), sum(), std(), linear algebra operations
#
# - Python Lists:
#   - Data Type: Python List Can store different data types (int, float, string, etc.) in the same list.
#   - Performance: Python List is Slower for numerical calculations.
#   - Memory Usage: Python List → Uses more memory.
#   - Python List → Can create nested lists, but handling is complex.
#   - Python List has Limited built-in mathematical functions.

# %% [markdown]
# ## Q7 What is a heatmap, and when should it be used?
#
# - What is a heatmap?
#   - A heatmap is a graphical representation of data where values are shown using colors.
#   - Instead of numbers, different colors represent different magnitudes (for example: darker color = higher value, lighter color = lower value).
# - when should it be used?
#   - To Show Correlation Between Variables
#   - Very useful in data analysis to see how strongly variables are related.
#     Example: Correlation matrix in pandas using Seaborn.
#   - To Compare Large Amounts of Data: When you have many values in a table and want to quickly identify: High or Low values, Patterns, Trends
#   - In Real-World Applications: Sales performance analysis, Website click tracking, Weather temperature maps, Exam score analysis

# %% [markdown]
# ## Q8 What does the term “vectorized operation” mean in NumPy?
#
# - In NumPy, a vectorized operation means performing calculations on entire arrays at once, instead of using loops.
#   Example:
#    ```
#    Without Vectorization (Using Loop)
#       import numpy as np
#       arr = np.array([1, 2, 3, 4])
#       result = []
#       for i in arr:
#          result.append(i * 2)
#       print(result)
# -  With Vectorization
#       import numpy as np
#       arr = np.array([1, 2, 3, 4])
#       result = arr * 2
#       print(result)    # output - [2 4 6 8]

# %% [markdown]
# ## Q9 How does Matplotlib differ from Plotly?
#
# - Matplotlib:
#   - Mostly static plots (basic zoom requires extra setup).
#   - Best for basic plots: Line plot, Bar chart, Histogram, Scatter plot
#   - Commonly used in: Jupyter Notebook, Research papers, Static reports
#   - Requires more customization for attractive plots.
#
# - Plotly:
#   - Highly interactive (zoom, hover, pan, tooltips by default).
#   - Great for: Interactive dashboards, 3D plots, Web-based visualizations, Animated charts
#   - Often used for: Web applications, Dashboards, Business analytics
#   - Modern and visually appealing by default.

# %% [markdown]
# ## Q10 What is the significance of hierarchical indexing in Pandas?
#
# - Hierarchical indexing (also called MultiIndex) in pandas allows you to have multiple levels of indexing on rows or columns in a DataFrame.
# - Organizes Complex Data: You can group data by more than one category.
#   Example: Data grouped by Department and Year at the same time.
# - Instead of creating many separate tables, you can store everything in one DataFrame with multiple index levels.
# - You can select data using multiple index levels.
#   - df.loc[("IT", 2024)] # This selects data for IT department in 2024.
# - Hierarchical indexing is commonly created after using: df.groupby(["Department", "Year"]).sum()
#
#   Example:
#    ```
#       import pandas as pd
#       data = {"Department": ["IT", "Sales", "HR", "Management"],
#                "Year": [2023, 2024, 2023, 2024],
#                "Salary": [50000, 60000, 40000, 45000]
#                }
#       df = pd.DataFrame(data)
#       result = df.groupby(["Department", "Year"]).sum()
#       print(result)

# %% [markdown]
# ## Q11 What is the role of Seaborn’s pairplot() function?
#
# - The pairplot() function in Seaborn is used to visualize relationships between multiple numerical variables in a dataset at once.
# - It creates a grid of plots showing: Scatter plots for every pair of variables, Distribution plots (histogram/KDE) on the diagonal
# - Each cell shows the relationship between two variables.
# - The diagonal shows the distribution of each variable.
# - Quickly detects relationships between variables
# - Helps identify patterns and correlations
# - Shows clusters when using the hue parameter
# - Useful in Exploratory Data Analysis (EDA)
#   Example:
#   ```
#       import seaborn as sns
#       import pandas as pd
#       df = sns.load_dataset("iris")
#       sns.pairplot(df, hue="species")

# %% [markdown]
# ## Q12 What is the purpose of the describe() function in Pandas?
# - The describe() function in pandas is used to generate summary statistics of a dataset.
# - It quickly provides important statistical details about numerical columns in a DataFrame.
# - For numerical data, it returns:
#    count → Number of non-null values
#    mean → Average value
#    std → Standard deviation
#    min → Minimum value
#    25% → First quartile
#    50% → Median
#    75% → Third quartile
#    max → Maximum value
#
#    Example:
#    ```
#        import pandas as pd
#        data = {"Age": [20, 21, 19, 22, 20],
#                 "Marks": [85, 90, 88, 92, 87]
#                 }
#        df = pd.DataFrame(data)
#        df.describe()
#
#        #output-
#
#                     Age       Marks
#         count    5.000000    5.000000
#         mean    20.400000   88.400000
#         std      1.140175    2.701851
#         min     19.000000   85.000000
#         25%     20.000000   87.000000
#         50%     20.000000   88.000000
#         75%     21.000000   90.000000
#         max     22.000000   92.000000

# %% [markdown]
# ## Q13 Why is handling missing data important in Pandas?
#
# - Handling missing data in pandas is important because missing values can affect accuracy, analysis results, and model performance.
# - Ensures Accurate Analysis: Missing values can give incorrect results for: Mean, Sum, Correlation, Statistical calculations.
# - Prevents Errors
# - Improves Data Quality
# - Better Machine Learning Performance
# - Remove missing values (dropna())
# - Fill missing values (fillna())
#   Example:
#   ```
#      import pandas as pd
#      data = {"Marks": [85, None, 90, 88]}
#      df = pd.DataFrame(data)
#      # Filling missing value with mean
#      df["Marks"].fillna(df["Marks"].mean(), inplace=True)
#      print(df)

# %% [markdown]
# ## Q14 What are the benefits of using Plotly for data visualization?
#
# - Plotly is a powerful visualization library widely used for creating interactive and web-based graphs.
# - Plotly charts support: Zooming, Panning, Hover tooltips, Click events, Toggle data on/off. All by default, without extra coding.
# - Supports Advanced Visualizations: You can easily create: 3D plots, Heatmaps, Choropleth maps, Animated charts, Financial charts
# - Plotly works very well with dashboards like: Dash (for building interactive web apps). This makes it popular in business analytics.
# - Plotly visualizations can be: Exported as HTML, Embedded in websites, Shared online
# - It integrates smoothly with: pandas, NumPy, Jupyter Notebook

# %% [markdown]
# ## Q15  How does NumPy handle multidimensional arrays?
#
# - NumPy handles multidimensional arrays using a special data structure called ndarray (N-dimensional array).
# - It allows you to store and work with data in 1D, 2D, 3D, or higher dimensions efficiently.
#   Example:
#   ```
#       import numpy as np
#       arr = np.array([[1, 2, 3],
#                   [4, 5, 6]])
#       print(arr)
#
#       # output-
#       arr3d = np.array([[[1, 2], [3, 4]],
#                         [[5, 6], [7, 8]]])
# - NumPy stores important information:
#   - arr.shape → Size of each dimension
#   - arr.ndim → Number of dimensions
#   - arr.size → Total number of elements
# - You can access elements using multiple indices: arr[0, 1]
# - Vectorized Operations: Operations apply to the entire array: arr * 2
# - Broadcasting Support: NumPy automatically adjusts shapes when possible to perform operations between arrays of different sizes.

# %% [markdown]
# ## Q16 What is the role of Bokeh in data visualization?
#
# - Bokeh as the "bridge" between the complex world of Python data analysis and the interactive world of the modern web browser.
# - Bokeh’s primary job is to provide "web-ready" interactivity. Out of the box, it includes a toolbar that allows users to: Pan and Zoom, Hover Tools, Linked Brushing
# - Handling Large Datasets: Standard browser-based tools often "choke" when trying to render 100,000+ points. Bokeh handles this via: Downsampling, WebGl Support.
# - Use Bokeh if: You are building a web dashboard, need real-time data streaming, or want your audience to "play" with the data.
# - Skip Bokeh if: You just need a quick, static chart for a slide deck or a printed report (Matplotlib or Seaborn are faster for this).

# %% [markdown]
# ## Q17  Explain the difference between apply() and map() in Pandas
#
# - map():
#   - map() is for specific transformations on a single column, while apply() is the "Swiss Army Knife" for more complex operations.
#   - It is a Series-only method. It works element-wise and is primarily used for substituting values or mapping one set of values to another.
#   - Works only on a single Column (Series).
#   - Best for: Using a dictionary or a function to transform categories.
#   - If you use a dictionary, any value not in that dictionary will become NaN (unless you use map().fillna()).
#     Example:
#     ```
#        df['gender'] = df['gender'].map({'M': 'Male', 'F': 'Female'})
#
# - apply():
#   - apply() is the "Swiss Army Knife" for more complex operations.
#   - It can work on both Series and DataFrames. It is designed to "apply" a function along an axis (either rows or columns).
#   - Best for: Complex logic that requires multiple columns or custom functions.
#   - You can choose to apply the function row-wise (axis=1) or column-wise (axis=0).
#   Example:
#   ```
#      # Calculating a bonus based on two different columns
#      df['total_comp'] = df.apply(lambda row: row['salary'] + row['bonus'], axis=1)

# %% [markdown]
# ## Q18 What are some advanced features of NumPy?
#
# 1. Broadcasting:
#    - Broadcasting in NumPy allows you to perform arithmetic operations on arrays of different shapes without manually reshaping them.
#    - It automatically expands the smaller array to match the shape of the larger array.
#    - NumPy compares their shapes from right to left.
#    - Two dimensions are compatible if: They are equal, or One of them is 1
# 2. Vectorization and Universal Functions (ufuncs):
#    - In standard Python, if you want to add 1 to every element in a list, you write a for loop. In NumPy, you just do arr + 1.
#    - Vectorization eliminates the overhead of Python’s internal loop.
#    - ufuncs (Universal Functions) like np.sin(), np.exp(), and np.add() are compiled functions that perform element-wise operations at near-hardware speeds.
# 3. Instead of slicing with integers like arr[0:5], advanced indexing allows you to use arrays as indices.
#    Boolean Masking: You can filter data using logical conditions. For example, arr[arr > 10] instantly returns all elements greater than 10.
#    Fancy Indexing: Passing a list of specific indices, like arr[[1, 5, 12]], to grab non-contiguous elements.
# 4. Use case: When you need the performance of NumPy but your data is heterogeneous and you don't want the overhead of a full Pandas DataFrame.
# 5. np.memmap allows you to map a file on your hard drive directly into a NumPy array.
#    NumPy loads only the specific "chunks" of data you are currently accessing, allowing you to process massive files seamlessly.

# %% [markdown]
# ## Q19 How does Pandas simplify time series analysis?
#
# - Pandas was originally created for financial data analysis, so time series support isn't just a "plugin"—it is baked into the library's core.
# - It simplifies time-based data by treating time as a first-class index rather than just a string or a number.
# 1. The Power of the DatetimeIndex
#    - The biggest game-changer is the DatetimeIndex. When you convert a column of dates to actual datetime objects and set them as your index, your DataFrame becomes "time-aware."
#    - Partial String Indexing: You don't need exact timestamps. You can grab all data from a year just by typing df['2023'] or a specific month with df['2023-05'].
#    - Slicing: You can slice ranges naturally: df['2023-01-01' : '2023-01-15'].
# 2. Resampling: The "Group By" for TimeIf you have data recorded every minute but want to see the average by day or month, you use .resample().
#    - It works like a groupby but understands calendar logic (leap years, business days, etc.).
#    - Downsampling: Aggregating high-frequency data to a lower frequency (e.g., Minutes -> Days).
#    - Upsampling: Increasing frequency (e.g., Days -> Hours) and using .ffill() (forward fill) or interpolation to fill the gaps.
# 3. In time series forecasting, you often need to compare today’s value to yesterday’s to calculate growth or momentum.
#    - .shift(1): Moves data down by one period (creating a "lag").
#    - .diff(): Calculates the statistical difference between time steps automatically (Value_t - Value_{t-1}).
# 4. Rolling Windows (Moving Averages): Pandas makes smoothing out noisy data incredibly easy with the .rolling() method. This is essential for calculating moving averages or volatility.
# 5. Effortless Time Zone Handling: Dealing with UTC vs. Local Time is usually a nightmare of manual offsets. Pandas uses tz_localize and tz_convert to handle daylight savings and international offsets with a single method call.

# %% [markdown]
# ## Q20 What is the role of a pivot table in Pandas?
#
# - A Pivot Table in Pandas as a way to "rotate" and summarize your data.
# - It takes a "long" dataset (lots of rows, few columns) and turns it into a "wide" dataset (a summarized grid), making it much easier to spot patterns.
# - A pivot table rearranges your data based on three main components:
#   - Index: The rows of your new table (the "Who/What").
#   - Columns: The headers of your new table (the "When/Where").
#   - Values: The numbers you want to summarize (the "How much").
# - Key Roles and Benefits:
#     1. Data Aggregation:
#        The most common use is to summarize data. By default, pivot_table() calculates the mean, but you can easily switch this to sum, count, min, max, or even custom functions.
#        Example: Instead of seeing 5,000 individual sales transactions, you can see the Total Sales per Region per Month.
#     2. Multi-Level Analysis (Grouping): You aren't limited to just one row or column. You can pass a list to the index or columns to create hierarchical layers.
#        Example: Break down sales by Region, then by Store Manager, and then by Product Category.
#     3. Handling Missing Data: Real-world data is messy. pivot_table() has a built-in fill_value parameter. If a certain salesperson didn't sell anything in June, the table would normally show NaN (Not a Number). You can tell Pandas to automatically replace those with 0.
#     4. Adding Grand Totals: By setting margins=True, Pandas automatically calculates the "All" row and column, giving you grand totals for your entire dataset instantly.
# - groupby() Returns a Series or a "Long" DataFrame. While pivot_table() Returns a "Wide" 2D grid (Matrix style).
# - groupby()	Readability	Harder for humans to read at a glance. While pivot_table() Designed for reporting and visualization.
# - groupby() Complexity	Better for programmatic data processing. While pivot_table() Better for quick data exploration and summaries.

# %% [markdown]
# ## Q21 Why is NumPy’s array slicing faster than Python’s list slicing?
#
# - Python List Slicing:
#   - Data Creation: Creates a new copy (slow).
#   - Memory: Fragmented (pointers everywhere).
#   - Type Checking: Happens for every element.
#   - Scaling: Slower as the slice gets larger.
# - NumPy Array Slicing:
#   - Data Creation: Creates a "view" (fast).
#   - Memory: Contiguous (all in a row).
#   - Type Checking: Happens once for the whole array.
#   - Scaling: Constant time (nearly the same for any size).

# %% [markdown]
# ## Q22 What are some common use cases for Seaborn?
#
# 1. Visualizing Distributions:
#    displot() and kdeplot(): These go beyond simple histograms by adding a Kernel Density Estimate (KDE), which creates a smooth curve over your data to show the "shape" of the distribution.
#    jointplot(): This allows you to see the distribution of two variables at once, showing their individual histograms on the margins and their relationship in the center.
# 2. Examining Relationships (Regression): Seaborn makes it incredibly easy to see if two variables are correlated.
#    regplot() and lmplot(): These don't just plot points; they automatically calculate and draw a linear regression line (the "line of best fit") along with a 95% confidence interval shadow.
#    Why it’s useful: You can instantly see if your data has a positive or negative trend without running a separate statistical model.
# 3. Categorical Data Comparison:
#    Comparing different groups (like "Sales by Region" or "Health Outcomes by Age Group") is where Seaborn shines.
#    boxplot() and violinplot(): These are essential for spotting outliers and seeing the "density" of data within categories. A violin plot is particularly advanced because it shows the distribution shape inside the plot itself.
#    catplot(): This allows you to create a grid of plots (faceting) to compare categories across multiple sub-plots.
# 4. Multi-Variable Discovery (The Pair Plot): One of Seaborn's "killer features" is the pairplot().
#    In one line of code, it creates a matrix of plots showing the relationship between every single numerical variable in your dataset.  It's the ultimate "exploratory" tool—you run it at the start of a project to see which variables actually matter.
# 5. Heatmaps for Correlation Matrices:
#    When you have dozens of variables, a heatmap() is the best way to see how they all relate to each other.
#    By calculating a correlation matrix in Pandas and passing it to Seaborn, you get a color-coded grid where bright colors represent high correlation.
#    Use case: Identifying redundant features in a machine learning dataset (feature selection).
# 6. Complex "Faceting" (Grid Plots)
#    If you want to see how a relationship changes across different subsets (e.g., "Tips vs. Total Bill" broken down by "Day of the Week" AND "Smoker status"), you use FacetGrid.
#    It automatically splits your data into a grid of small, synchronized charts, keeping the scales consistent so you can compare them accurately.

# %% [markdown]
# <h3 align = "Center"><b>Practical</b><h3>

# %% [markdown]
# ## Q1 How do you create a 2D NumPy array and calculate the sum of each row?

# %%
import numpy as np

data = np.array([[1, 2, 4], [5, 6, 7], [8, 9, 10]]) # 3 x 3 2D array
print(data)
# Out:
# [[ 1  2  4]
#  [ 5  6  7]
#  [ 8  9 10]]

# %% [markdown]
# ## Q2 Write a Pandas script to find the mean of a specific column in a DataFrame

# %%
import pandas as pd

data = { "Designation": ["Sales", "HR", "SDE"],
        "Age": [20, 40, 25],
        "Salary": [50000, 80000, 60000]

}

df = pd.DataFrame(data) 

# Calcualte the mean of salary
average_salary = df.Salary.mean()

print(average_salary)
# Out:
# 63333.333333333336

# %% [markdown]
# ## Q3 Create a scatter plot using Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

x = np.random.randn(500)
y = np.random.randn(500)
plt.scatter(x, y, color = "b")
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
## Another way to create scatter plot

x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]

plt.plot(x,y1, color = "r", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label = "y1")
plt.plot(x, y2, color = "b", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label = "y2")

plt.title("Scatter plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.legend()
plt.show()

# %% [markdown]
# ## Q4  How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?

# %%
import seaborn as sns

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 = tips[["total_bill", "tip", "size"]]
df1
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
sns.heatmap(df1.corr(), cmap = "coolwarm", annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Q5 Generate a bar plot using Plotly

# %%
import plotly.io as pio
# This forces Plotly to save a static PNG inside the notebook file
pio.renderers.default = "png"

import plotly.graph_objects as go
import plotly.express as px

fig = go.Figure()
fig.add_trace(go.Bar(x = [1, 4, 6], y = [8, 9, 5]))

# %%
# another way

x = [1, 4, 6]
y = [8, 9, 5]
fig = px.bar(x = x, y = y)
fig.show()

# %% [markdown]
# ## Q6  Create a DataFrame and add a new column based on an existing column

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Ticket": [25, 30, 35],
    "Fare": ["125", "150", "175"]
}

df = pd.DataFrame(data)

df
# Out:
#       Name  Ticket Fare
# 0    Alice      25  125
# 1      Bob      30  150
# 2  Charlie      35  175

# %%
df["Tax"] = df["Fare"].astype(float) * 0.10
df
# Out:
#       Name  Ticket Fare   Tax
# 0    Alice      25  125  12.5
# 1      Bob      30  150  15.0
# 2  Charlie      35  175  17.5

# %% [markdown]
# ## Q7  Write a program to perform element-wise multiplication of two NumPy arrays

# %%
import numpy as np

arr1 = np.array([2, 4, 6])
arr2 = np.array([1, 3, 5])

multiply_arr = arr1 * arr2
print(multiply_arr)
# Out:
# [ 2 12 30]

# %% [markdown]
# ## Q8 Create a line plot with multiple lines using Matplotlib

# %%
import matplotlib.pyplot as plt

x = [50, 70, 90]
y1 = [60, 90, 40]
y2 = [70, 50, 80]

plt.plot(x, y1, color = "r", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label = "y1")
plt.plot(x, y2, color = "b", marker = "o", linestyle = "--", linewidth = 3, markersize =6, label = "y2")

plt.xlabel = "x-axis"
plt.ylabel = "y-axis"
plt.title = "Multiple Line plot"
plt.legend()
plt.show()

# %% [markdown]
# ## Q9  Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "Mia"],
    "Ticket": [45, 30, 35, 10],
    "Fare": ["225", "150", "175", "100"]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Ticket Fare
# 0    Alice      45  225
# 1      Bob      30  150
# 2  Charlie      35  175
# 3      Mia      10  100

# %%
threshold = 150

max_Tickets_soldby = df[df["Fare"].astype(int) > threshold]
print(max_Tickets_soldby)
# Out:
#       Name  Ticket Fare
# 0    Alice      45  225
# 2  Charlie      35  175

# %% [markdown]
# ## Q10 Create a histogram using Seaborn to visualize a distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt


tips = sns.load_dataset("tips")
sns.histplot(data = tips, x = "total_bill", color = "b")
plt.title("Histrogram")
plt.xlabel("Total Bill")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Q11 Perform matrix multiplication using NumPy

# %%
import numpy as np

arr1 = np.random.randint(1, 3, (3,3))
arr2 = np.random.randint(1, 3, (3,3))

# %%
arr1
# Out:
# array([[1, 2, 2],
#        [2, 1, 1],
#        [1, 2, 2]], dtype=int32)

# %%
arr2
# Out:
# array([[1, 2, 1],
#        [2, 1, 1],
#        [1, 2, 2]], dtype=int32)

# %%
# 1st method
arr1 @ arr2
# Out:
# array([[7, 8, 7],
#        [5, 7, 5],
#        [7, 8, 7]], dtype=int32)

# %%
arr1 * arr2
# Out:
# array([[1, 4, 2],
#        [4, 1, 1],
#        [1, 4, 4]], dtype=int32)

# %%
np.dot(arr1, arr2)
# Out:
# array([[7, 8, 7],
#        [5, 7, 5],
#        [7, 8, 7]], dtype=int32)

# %% [markdown]
# ## Q12  Use Pandas to load a CSV file and display its first 5 rows

# %%
import pandas as pd

df = pd.read_csv('taxonomy.csv')
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df[0:6]
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash
# 5   101-02-03     Help Pay for Housing    101-02  Emergency Cash

# %% [markdown]
# ## Q13 A Create a 3D scatter plot using Plotly.

# %%
import plotly.graph_objects as go
import plotly.express as px

x = [1, 2, 3, 4]
y = [5, 8, 12, 3]
z = [3, 4, 5, 6]

fig = px.scatter_3d(x = x, y = y, z = z)
fig.show()

fig.write_html("my_3d_plot.html")
