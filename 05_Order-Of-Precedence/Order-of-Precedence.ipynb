# %% [markdown]
# ## Order of precedence -- like we have Bodmas in maths in python to execution of code we have precedence
#  i.e. Execution of python statement will be from left to right
# ex.
# b=5
# b+=8
#
# ANS- 13  # first it did addition then assign 13 value to b
#
# 2+3-8
# ANS- -3  # first 2+3 = 5 and 5 -8 = -3
#
# ## always first paranthesis
# (5+3) - 4
# ANS- 4   # first solved paranthesis then substarction
#
# 4 - (3+5)
# ANS- -4   # first solved paranthesis then substarction
#
#
# (10+5) + (8/2)
# 19        # first it will start from left i.e. 10+5 then 8/2 then will do addition
#
#
#
# except exponential it is solved from right to left  -- see the resource docs file
