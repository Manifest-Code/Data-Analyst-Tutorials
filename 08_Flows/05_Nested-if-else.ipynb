# %%
x = 1
y = 6

if x > 5:
    if y > 5:
        print("Both x and y are greater than 5")
    else:
        print("x is greater than 5 but y is not greater than 5")
else:
    print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
is_VIP = True
age = 25

if (is_VIP):
	if (age>=18):
		if (age <65):
			print("welcome VIP customer")
		else:
			print("you are eligible for seneior cetezen Discount")
	else:
		print("VIP status is only for adults")
else:
    print("You are not VIP customer and will charge normal charges")
# Out:
# welcome VIP customer

# %% [markdown]
# a= input("Enter a number")                   ## input value is always a string
# print("The no. is, a, type(a)")
#
# ANS- Enter a number 5
#      The no. is 5 <class 'str'>
#
#
# a= int(input("Enter a number"))
# print("The no. is, a, type(a)")
#
# ANS- Enter a number 6
#      The no. is 6 <class int>

# %% [markdown]
# Name= input("please enter your name")
# email_ID= input("please enter yor mail id")
# password = input("please enter your password")
#
# if (Name == ""):
#     print("Please enter valid name, name can not be empty")
# else:
#     if ("@" not in email):
# 	   print("Please enter valid email")
# 	else:
#        if len(password) <0:
# 	     print("Please provid valid password")
# 		 else:
# 		   print("login registration is successful")
