# %%
# if elif else - for Multipule coditions  if there are multiple conditions(under elif block) whaterver first condition is true will be executed remaining will be skip 
# even if they are true.**

a=10
if (a>10):
 print("a is greater than 10")
 
elif (a<10):
 print("a is less than 10")
 
else:
   print("a is Equals to 10")
# Out:
# a is Equals to 10

# %%
if (a<10):
 print("a is less than 10")
 
elif (a>2000):                        # this elif condition is satisfied so it will print this value and will skip other elif statements even its true
 print("a is huge")
 
elif (a>10):
 print("a is greater than 10")
 
else:
   print("a is Equals to 10")
# Out:
# a is Equals to 10

# %%
score = 30
if (score >= 90):
    print("Grade A")
elif (80<=score<90):
    print("Grade B")
elif (70<=score<80):
    print("Grade C")
else:
    print("Grade D")
# Out:
# Grade D
