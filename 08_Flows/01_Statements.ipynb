# %% [markdown]
# ## There are different types of statesments use in python to code:
#   💎 Assignment statement
#   💎 Loop statements
#   💎 Condition statements
#   💎 Expression statements

# %%
# Assignment statement
a=3
a
# Out:
# 3

# %%
# Expression statement
a=3
b=5
a+b
# Out:
# 8

# %% [markdown]
# | Conditional Statements | Loop Statements | Control Statements |
# |------------------------|-----------------|--------------------|
# | if                     | for             | continue           |
# | if–else                | while           | break              |
# | if–elif–else           |                 |                    |
# | nested if–else         |                 |                    |
