# %% [markdown]
# ## 📗🍁 Introduction to Python ✨
#
# Python is a high-level and easy-to-learn programming language. It is designed to be simple, so beginners can understand and write code easily.
#
# ## Python is widely used in many areas such as:
#  💎Web development
#  💎Data analysis
#  💎Artificial Intelligence and Machine Learning
#  💎Automation and scripting
#  💎Software development
#
# ## Why Python is widwly used?
# Python provides industry-standard libraries such as NumPy, Pandas, Matplotlib, Seaborn, and Scikit-learn, which make working with large datasets efficient and intuitive.
# Its ability to integrate with tools like Jupyter Notebook makes Python ideal for exploratory data analysis and building data-driven solutions.
#
# ## What is IDE?
# Integrated Development Environment softwares - It is a platform (Environment) where one can write the code.
# ex. VS code, pycham, Google colab
#
# ## ASCII -American statndard code for information  Interchange - 2 to the power 8 -128 charachter encoded
# ## UTF - uniform transformation format - 2 to the power 16 - almost encoded all characters

# %%
# ASCII representation
char = 'A'
ord(char) #ordinal, numerical order of a character
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
ord('a')
# Out:
# 97

# %%
ord('B')
# Out:
# 66

# %%
ord('b')
# Out:
# 98

# %%
'\u03A9' # Unicode for Greek capital letter Omega
# Out:
# 'Ω'

# %%
'\u0975' # Unicode for Devanagari letter 'a'
# Out:
# 'ॵ'
