# %% [markdown]
# #why do we need visualisation? #summarisation of data
# #matplotlib, seaborn, plotly, bokeh
# #matplotlib>> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore') #suppress all the warnings

# %%
#line, scatter, bar, histogram, pie chart, box plot, violin plot

# %%
#generate random numbers in numpy
x = np.random.rand(50)

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50)
# Out:
# array([ 0.67222544,  0.3866191 ,  0.7161527 , -0.72658616,  0.39899733,
#        -0.20020483, -0.19577148, -0.80985447,  0.15297476, -0.20389043,
#         0.78965915,  1.19348753,  0.90593466, -1.07859545,  1.54813224,
#        -0.40554163, -0.92506855, -2.10520994,  1.31781519, -0.47838064,
#         0.48730031,  0.19657978, -1.52444231, -0.64286972, -0.50160792,
#         0.39938568,  1.49866058, -0.30873044, -0.22971804, -1.00242218,
#         0.97332466,  0.42095791, -0.4476505 , -0.95273905, -0.51707246,
#        -0.04741866,  1.35097907, -1.2399877 ,  0.32165056, -1.17205086,
#        -1.21466774,  1.86757158,  0.77972638,  0.87032581, -0.00464651,
#         0.09371065,  0.24218728, -0.68863014,  0.34744974, -1.05133187])

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['Data'], index = pd.date_range('2024-07-11', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-07-11  0.631787
# 2024-07-12 -0.054954
# 2024-07-13  3.085517
# 2024-07-14  1.200355
# 2024-07-15  2.098577
# ...              ...
# 2027-04-02 -0.283567
# 2027-04-03  0.554655
# 2027-04-04  0.202114
# 2027-04-05 -0.316387
# 2027-04-06 -0.531804
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8)) #summary>> most of the values are fluctuating between -2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.44072316, 0.27802208, 0.59679096, 0.87436922, 0.71260385,
#        0.5626826 , 0.94153046, 0.24272076, 0.26522535, 0.43211814,
#        0.8915844 , 0.45483901, 0.85697661, 0.84603208, 0.77657009,
#        0.87244493, 0.62929687, 0.19216634, 0.67082408, 0.45569266,
#        0.34117122, 0.12260126, 0.95971724, 0.16751751, 0.20341394,
#        0.8684109 , 0.74446144, 0.70658932, 0.27163455, 0.46800262,
#        0.92602616, 0.75409055, 0.68613518, 0.7383948 , 0.33949352,
#        0.34835102, 0.90610492, 0.05419716, 0.85124297, 0.21169542,
#        0.33977473, 0.22835545, 0.51444497, 0.30148323, 0.53541559,
#        0.09610403, 0.01936322, 0.31413606, 0.59476337, 0.81130868])

# %%
y = np.random.rand(50)
y
# Out:
# array([0.19314672, 0.43269815, 0.78852681, 0.5954203 , 0.73273866,
#        0.32320413, 0.26367051, 0.78755028, 0.859113  , 0.0381668 ,
#        0.6987685 , 0.75019038, 0.56519055, 0.7997172 , 0.38345601,
#        0.91904708, 0.97698114, 0.20745979, 0.26136394, 0.23343056,
#        0.93315203, 0.61002588, 0.90299563, 0.36009241, 0.803816  ,
#        0.99528597, 0.27969006, 0.57390347, 0.26600382, 0.58542971,
#        0.00200225, 0.70609181, 0.63155347, 0.20253168, 0.39234204,
#        0.03604486, 0.46520139, 0.40734864, 0.00295397, 0.78390276,
#        0.93123609, 0.33934277, 0.50979229, 0.41537044, 0.07582896,
#        0.75021473, 0.69898904, 0.36744639, 0.04628103, 0.19789216])

# %%
#scatter plot >> A scatter plot is a type of data visualization that displays values for two variables as points on a Cartesian plane. Each point represents the value of one variable corresponding to the value of the other variable
plt.scatter(x, y)

# %%
#line plot
#whenever you want to depict the relation between two variables in the form of trend
#mostly in x axis the date - time column is there
x = [1, 2, 3, 4, 5] #assume x is no of day
y = [5, 2, 7, 8, 1] #y is price of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()   # fromal way to show the plot, removes unnecessary text and gives a clean plot

# %%
plt.plot(x, y, color = "red")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
x, y
# Out:
# ([1, 2, 3, 4, 5], [5, 2, 7, 8, 1])

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--')
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x, y, color = "red", marker = "o", linestyle = '--', linewidth = 4, markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]

plt.plot(x, y1, color = "red", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y1 as tata motors")
plt.plot(x, y2, color = "b", marker = "o", linestyle = "--", linewidth = 3, markersize = 6, label="line y2 as tata power")

plt.title("Multiple lines in one plot")

plt.xlabel("Days")
plt.ylabel("stock price")
plt.legend()  # it will show the label of the line in the plot given in plt.plot() function

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure() #initialising a page to make plot
plt.subplot(1, 2, 1) # 1 is 1 row, 2 is 2 columns and 1 is the 1st page
plt.plot(x, np.sin(x))

plt.subplot(1, 2, 2)   # 1 is 1 row, 2 is 2 columns and 2 is the 2nd page
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure() #initialising a page to make plot
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.sin(x+1))

plt.show()

# %%
plt.plot(x, np.sin(x), color = 'blue')

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')   #previous one was compressed so this makes the x and y axis equal in scale
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>> continuous numerical data

data = np.random.randn(1000) #by default 10 bins are created (10 bars are created)
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, color = 'r', bins = 20)
plt.show()

# %%
#stacked histogram >> two histograms together
data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
data1
# Out:
# array([ 0.38228848,  0.58229703,  0.16777567, ...,  0.13164947,
#         1.73226249, -0.23635012], shape=(5000,))

# %%
data2
# Out:
# array([6.42109329, 7.40673028, 6.33405216, ..., 6.8149796 , 2.25855596,
#        6.35968824], shape=(5000,))

# %%
plt.hist([data1, data2], bins = 20, color = ['r', 'b'], label = ['dist1', 'dist2'])
plt.xlabel("Values")
plt.ylabel('frequency')
plt.title("stacked histogram")
plt.show()

# %%
#scatterplot >> to understand the relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)
x
# Out:
# array([0.81796262, 0.19105695, 0.3511315 , 0.42184783, 0.21253613,
#        0.56940192, 0.20485347, 0.48436021, 0.54808456, 0.89037753,
#        0.70185043, 0.09355518, 0.00540561, 0.48960977, 0.48089726,
#        0.46940178, 0.63471968, 0.32679134, 0.63732533, 0.43396687,
#        0.54947714, 0.76588799, 0.01666369, 0.12251121, 0.70597763,
#        0.18766664, 0.39858307, 0.34666517, 0.6088576 , 0.1211896 ,
#        0.27549266, 0.40947013, 0.75411673, 0.66501597, 0.38450466,
#        0.40543565, 0.34035052, 0.57502322, 0.23272285, 0.13775098,
#        0.69743635, 0.08214466, 0.13323702, 0.13100235, 0.35618267,
#        0.27010799, 0.53391345, 0.04584445, 0.63071672, 0.08185633])

# %%
y
# Out:
# array([0.82116822, 0.10385516, 0.92202223, 0.49849838, 0.49933812,
#        0.54445191, 0.46461836, 0.73030996, 0.70693255, 0.40816994,
#        0.49055767, 0.56645233, 0.10214601, 0.87111772, 0.19781958,
#        0.55686451, 0.00692729, 0.30646299, 0.62669321, 0.79435   ,
#        0.78104546, 0.05053093, 0.26319843, 0.41447622, 0.40058563,
#        0.87820859, 0.6343618 , 0.74297568, 0.69029967, 0.90854148,
#        0.93209305, 0.06063911, 0.91214129, 0.06678106, 0.95972486,
#        0.86536865, 0.20748263, 0.13462103, 0.77973779, 0.6381056 ,
#        0.2846662 , 0.07127083, 0.89731407, 0.74713998, 0.02412052,
#        0.49646586, 0.78771356, 0.66813808, 0.81131185, 0.24381824])

# %%
plt.scatter(x, y, c = 'r', marker = "X")

# %%
#bar plot >> To see the districution of categorical variables
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.bar(x, y, color = 'r') #vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.barh(x, y, color = 'r') #horizontal plot
# Out:
# <BarContainer object of 4 artists>

# %%
#pie char >> To understand the percent distribution of data
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%")
plt.title("Pie chart")
plt.show()

# %%
#focus on one segment
explode = (0.0, 0.1, 0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%", explode = explode)
plt.title("Pie chart")
plt.show()

# %%
explode = (0.0, 0.1, 0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%", explode = explode, shadow = True)
plt.title("Pie chart")
plt.show()

# %%
#3d plot >> 3 dimesion plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='red')

# %%
data = pd.read_csv("Bank_Churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
plt.scatter(x = data['Age'], y=data["Balance"])

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'], color = 'red')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Balance'], color = 'red')
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
#Boxplot  >> to check the distribution of data and outliers(extreme/abnormal values)
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x1d149988b60>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1d1494be8a0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1d1491b8530>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1d1499d6120>}

# %%
years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

plt.stackplot(years, category1, category2, category3, labels = ["category1", "category2", "category3",],
             colors = ["skyblue","lightgreen", "orange"])
plt.xlabel("years")
plt.ylabel("Values")
plt.title("Area plot")
plt.legend()
plt.show()
